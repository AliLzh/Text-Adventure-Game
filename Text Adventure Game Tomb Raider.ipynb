# %%
"""
    DocString:
    
    DocString:
    
    A) Introduction:
    This game is based on the movie Lara Croft Tomb Raider: The Cradle of Life 
    (2003). This game includes four or five stages, depending on the choices 
    you make. Keep in mind that making ethical decisions and having some knowledge 
    from this movie will be helpful.
    
    Round 1: Decide whether to have a partner in this journey or not.
    Round 2: Save partner from the prison. (Optional)
    Round 3: Enter the entrance of "Cradle of Life" - Crater.
    Round 4: Defeat the crime group.
    Round 5: Gain the Pandora's Box.
    
    B) Known Bugs and/or Errors:
    None
    
"""

# Define user function
def start():
  
    # Print a statement to introduce the backgroud of this game 
    print("""
Dear explorer, you are on a journey to pursue "Pandora's Box." It is the 
mysterious treasure of the ancient world, supposedly containing an enormous 
power that is enough to destroy the entire human race. However, such a treasure 
full of mighty power naturally attracted the evil forces prying eyes. Your 
mission is to find out this box before others to save the world ...\n
          """)
    
    # Prompt users to input enter to continue the game
    input(prompt = "<Press enter to continue>\n")
    
    starting_path() # This moves us into starting_path
    

# Define user function    
def starting_path():
    
    # Print a statement and give the users' choices
    print("""
Before this adventure, you decide whether to recruit your old flame Terry 
Sheridan a former mercenary and Royal Marine currently in prison in the Republic 
of Kazakhstan, as a partner? (A or B)

A. Yes, it sounds no bad.
B. No, I rather go by myself!\n
          """)
    
    # Input for users to put their choice
    choice_1 = input(prompt = ">  \n")
    
    # Convert the player's input() to lower case
    choice_1 = choice_1.casefold()
    
    # Conditional statement
    # Control users' input and reduce the bug
    if 'a' in choice_1 or "yes" in choice_1 or "partner" in choice_1:
        print("""
Now you are on your way to the prison in Republic of Kazakhstan. Are you ready?\n
              """)
        
        # Prompt users to input enter to continue the game
        input(prompt = "<Press enter to continue>\n")
        prison() # This moves us into prison
    
    # Control users' input and reduce the bug
    elif 'b' in choice_1 or "no" in choice_1 or "myself" in choice_1:
        print(""" 
The various clues you have collected show that the bottom of the moon temple 
is the legendary "Pandora's Box" buried place...\n
              """)
        crater() # This moves us into crater
        
    else:
        # Ask users to try to make a new input
        print("Try again!(A or B?) You can do it!\n")
        
        # Prompt users to input enter to continue the game
        input(prompt = "<Press enter to continue>\n")
        
        starting_path() # This moves us back to starting_path
    # End of this conditional statement
        

# Define user function        
def prison():
    
    # Print a statement and give the users' choices
    print("""
There are many jailers on patroling... What would you like to do? (A, B, or C)

A. Self-disguise, sneak on to the jail, then find a good timing to save him.
B. Enter and fight jailers directly face to face!
C. Oh my god, I regret, I think without a partner sounds not bad.\n
          """)
    
    # Input for users to put their choice
    choice_2 = input(prompt = ">  \n")
    
    # Convert the player's input() to lower case
    choice_2 = choice_2.casefold()
    
    # Start of nested Conditional Statement
    # Control users' input and reduce the bug
    if 'a' in choice_2 or 'self-disguise' in choice_2:
        print("""
Now you are inside of the jail, in order to save your 'partner', you should roll
a dice. Once your dice shows an even number, you pass this game.
              """)
        
        # Import random for roll a dice game
        import random
        
        # Prompt users to input enter to start roll a dice game
        input(prompt = "<press enter to start roll a dice>\n")
        
        dice = random.randint(a = 1,
                              b = 6)
        
        # Print with a dynamic string
        print(f"""
You start rolling a dice, the result you get is {dice}.        
        """)
        
        # Conditional Statement
        if dice > 3:
            print("""
You guys successfully escape from prison!\n
                 """)
            crater_1() # This moves us into crater_1
        
        else:
            print("""
Unfortunately, you loss this game
suddenly you loss your memory...
                 """)
            prison() # This moves us back to prison 
    
    # Control users' input and reduce the bug
    elif 'b' in choice_2 or 'fight' in choice_2:
        print("""
The alarm ringing, more and more patrols coming, you are being catch by them.\n
              """)
        fail()
    
    # Control users' input and reduce the bug
    elif 'run' in choice_2 or 'escape' in choice_2:
        starting_path() # This moves us back to starting_path
              
    else:
        # Ask users to try to make a new input
        ("Try again!(A or B or C?) You can do it!\n")
        
        # Prompt users to input enter to continue the game
        input(prompt = "<Press enter to continue>\n")
        
        prison() # This moves us back to prison 
     # End of this nested conditional statement   

# Define user function
def crater():
    
    # Print a statement and give the users' choices
    print("""  
From the tribe's chieftain stating that the Cradle of Life is in a crater 
protected by "Shadow Guardians (humanoid creatures which kill without hesitation 
when they sense a movement)...

With the help of clues, you arrive at the entrance of the Cradle of Life-the 
crater, you decide? (A, B, or C)

A. Fight with "Shadow Guardians" and enter
B. Taking a rest and take a moment to think
C. Runaway... I prefer not to die today
          """)
    
    # Input for users to put their choice
    choice_3 = input(prompt = ">  \n")
    
    # Convert the player's input() to lower case
    choice_3 = choice_3.casefold()   
    
    # Conditional Statement  
    # Control users' input and reduce the bug
    if 'a' in choice_3 or 'fight'in choice_3 or 'shadow guardians' in choice_3:
       
        # Start of nested conditional and while loops
        answer = 18
        chances = 3
        
        while chances > 0:
            
            # Insert a challenge game
            number = input(prompt = """
Passing this game to defeat the 'Shadow Guardians':

Fill in the numbers corresponding to the letter 'R' in "The Cradle of Life" 
(A-Z correspond to 1-26 respectively),
            
T=20; H=8; E=5; C=3; R=?; A=1; D=4; L=12; E=5; O=15; F=6; L=12; I=12; F=6; E=5\n""")
            print(f"\n R = {number}.")
            
            # Control users' input
            try:
                number = int(number)
                
            except:
                print("""Hint: the answer is aa integer number between 1-26""")
            
            if number == answer:
                print("""
You successfully defeat the Shadow Guardians, and you can now enter the Moon 
Temple...\n""")  
                moon_temple() # This moves us into moon_temple
                break # Break the loop
                
            elif number != answer:
                chances -= 1 
                
                if chances > 0:
                    # Print with a dynamic string
                    print(f"""
It is not correct, you have {chances} chances left, try again!""")
                    
                elif chances == 0:
                    print("""
That's incorrect. Shadow Guardiances kill you into pieces.\n""")
                    
                else:
                    fail()
                
            else:
                fail()
        # End of while loops
    
    # Control users' input and reduce the bug
    elif 'b' in choice_3 or 'rest' in choice_3 or 'think' in choice_3:
        print("""
10000000000 minutes later... Now you already take a good rest, what do you want 
to do next?\n
              """)
        crater() # This moves us back to crater 
    
    # Control users' input and reduce the bug
    elif 'c' in choice_3 or 'run' in choice_3:
        fail()
        
    else:
        # Ask users to try to make a new input
        ("Try again!(A or B or C?) You can do it!\n")
        
        # Prompt users to input enter to continue the game
        input(prompt = "<Press enter to continue>\n") 
        
        crater() # This moves us back to crater
    # End of this nested conditional statement

        
# Define user function
def crater_1():
    
    # Print a statement and give the users' choices
    print("""  
From the tribe's chieftain stating that the Cradle of Life is in a crater 
protected by "Shadow Guardians (humanoid creatures which kill without hesitation 
when they sense a movement)...

With the help of clues, you arrive at the entrance of the Cradle of Life-the 
crater, you decide? (A, B, or C)

A. Fight with "Shadow Guardians" and enter
B. Taking a rest and take a moment to think
C. Runaway... I prefer not to die today\n
           """)
    
    # Input for users to put their choice
    choice_4 = input(prompt = ">  \n")
    
    # Convert the player's input() to lower case
    choice_4 = choice_4.casefold()
    
    # Conditional Statement
    # Control users' input and reduce the bug
    if 'a' in choice_4 or 'fight'in choice_4 or 'Shadow Guardians' in choice_4:
        
        # Start of while loops
        answer_1 = 18
        chances_1 = 3
        while chances_1 > 0:
            
            # Insert a challenge game
            number_1 = input(prompt = """
Passing this game to defeat the 'Shadow Guardians':

Fill in the numbers corresponding to the letter 'R' in "The Cradle of Life" 
(A-Z correspond to 1-26 respectively),
            
T=20; H=8; E=5; C=3; R=?; A=1; D=4; L=12; E=5; O=15; F=6; L=12; I=12; F=6; E=5\n""")
            
            print(f"\n R = {number_1}.")
            
            # Control users' input
            try:
                number_1 = int(number_1) 
                
            except:
                print("""Hint: the answer is an integer number between 1-26.\n""")
            
            # Start of nested conditional
            if number_1 == answer_1:
                print("""
You successfully defeat the Shadow Guardians, and you can now enter the Moon 
Temple...\n
                      """)
                moon_temple_1() # This moves us into moon_temple_1
                break
                
            elif number_1 != answer_1:
                chances_1 -= 1
                
                if chances_1 > 0:
                    # Print with a dynamic string
                    print(f"""
It is not correct, you have {chances_1} chances left, try again!""")
                      
                elif chances_1 == 0:
                    print("""
That's incorrect. Shadow Guardiances kill you into pieces.\n
                          """)
                
                else:
                    fail()
                  
            else:
                fail()
            # End of while loops
    
    # Control users' input and reduce the bug
    elif 'b' in choice_4 or 'rest' in choice_4 or 'think' in choice_4:
        print("""
10000000000 seconds later... Now you already take a good rest, what do you want 
to do next?\n
              """)
        crater_1() # This moves us back to crateer_1
    
    # Control users' input and reduce the bug
    elif 'c' in choice_4 or 'run' in choice_4:
        fail()
        
    else:
        # Ask users to try to make a new input
        ("Try again!(A or B or C?) You can do it!\n")
        
        # Prompt users to input enter to continue the game
        input(prompt = "<Press enter to continue>\n") 
        
        crater_1() # This moves us back to crater_1
    # End of this nested conditional statement


# Define user function        
def moon_temple():
    
    # Print a statement and give the users' choices
    print("""
Now, you are in Moon Temple. The evil forces- crime lord Chen Lo and its groups 
tail after you and follow you into the Moon Temple. It is a labyrinthine cavern 
made of some strange crystalline substance. Inside there is a pool of highly 
corrosive black acid that holds the box...

Seeing that Chen Lo and his group are going to take Pandora's Box, you decide? 
(A or B)

A. Of course, run away!
B. Fighting for the Pandora's Box.
           """)
    
    # Input for users to put their choice
    choice_5 = input(prompt = ">  \n")
    
    # Convert the player's input() to lower case
    choice_5 = choice_5.casefold()
    
    # Conditional Statement
    # Control users' input and reduce the bug
    if 'a' in choice_5 or 'run' in choice_5:
        print("""
The crime group found Pandora's Box and opened it. Instantly, the human world 
was destroyed by the mysterious power...\n
              """)
        fail()
    
    # Control users' input and reduce the bug
    elif 'b' in choice_5 or 'fight' in choice_5 or 'pandora' in choice_5:
        print("""
You already tried your best to go against them, but too strong to go against 
the whole crime group by yourself. Finally, you sacrifice... People will not 
forget you as a hero!\n
              """)
        fail()
        
    else:
        # Ask users to try to make a new input
        ("Try again!(A or B?) You can do it!\n")
        
        # Prompt users to input enter to continue the game
        input(prompt = "<Press enter to continue>\n") 
        
        moon_temple() # This moves us back into moon_temple
    # End of this conditional statement


# Define user function
def moon_temple_1():
    
    # Print a statement and give the users' choices
    print("""
Now, you are in Moon Temple. The evil forces- crime lord Chen Lo and its groups 
tail after you and follow you into the Moon Temple. It is a labyrinthine cavern 
made of some strange crystalline substance. Inside there is a pool of highly 
corrosive black acid that holds the box...

Seeing that Chen Lo and his group are going to take Pandora's Box, you decide? 
(A or B)

A. Of course, run away!
B. Fighting for the Pandora's Box.\n
           """)
    
    # Input for users to put their choice
    choice_6 = input(prompt = ">  \n")
    
    # Convert the player's input() to lower case
    choice_6 = choice_6.casefold()
    
    # Conditional Statement
    # Control users' input and reduce the bug
    if 'a' in choice_6 or 'run' in choice_6:
        print("""
The crime group found Pandora's Box and opened it. Instantly, the human world 
was destroyed by the mysterious power...\n
              """)
        fail()
    
    # Control users' input and reduce the bug
    elif 'b' in choice_6 or 'fight' in choice_6 or 'pandora' in choice_6:
        print("""
You and Terry cooperate, Terry distracted Chen Lo, you knocked it into the acid 
pool, and he was being dissolved...\n
              """)
        pandora() # This moves us to pandora
    
    else:
        # Ask users to try to make a new input
        ("Try again!(A or B?) You can do it!\n")
        
        # Prompt users to input enter to continue the game
        input(prompt = "<Press enter to continue>\n") 
        
        moon_temple_1() # This moves us back into moon_temple_1
    # End of this conditional statement
 
    
# Define user function
def pandora():
    
    # Print a statement and give the users' choices
    print("""
At this moment, your old flame Terry 
tries to take Pandora's Box as compensation for finding it. 

At this moment, you decide? (A, B, or C)

A. Let you beloved one take away the Pandora's Box.
B. Firmly refusing, even though you deeply love him. You end up being forced 
   to shoot Terry in self-defense.
C. You can not choose between Pandora's Box and your beloved Terry. So while 
   you pretend to give him the Pandora's Box and hug him, you jump into the 
   acid pool with him and the Pandora's Box in your arm...\n
         """)
    
    # Input for users to put their choice
    choice_7 = input(prompt = ">  \n")
    
    # Convert the player's input() to lower case
    choice_7 = choice_7.casefold()
    
    # Control users' input and reduce the bug
    if 'a' in choice_7 or "beloved" in choice_7:
        print("""
The Pandora's Box being open. Instantly, dark clouds and the human world was 
destroyed by the mysterious power...\n
             """)
        fail()
    # Control users' input and reduce the bug    
    elif 'b' in choice_7 or 'refuse' in choice_7:
        print("""
Finally, you get Pandora's Box. This box has a fatal attraction for you, 
you decide? (A or B)

A. Open it! Too attractive, I can not bear to not open it. 
B. You realize that Pandora's Box is not supposed to be found, and you decide 
   to put it into the pool of acid... \n 
              """)
        
        # Input for users to put their choice
        choice_8 = input(prompt = ">  \n")
        
        # Convert the player's input() to lower case
        choice_8 = choice_8.casefold()
        
        # Start of nested conditional 
        # Control users' input and reduce the bug
        if 'a' in choice_8 or 'open' in choice_8:
            
            # Start of while loops
            chances_1 = 2
            while chances_1 >= 0:
                
                password = input(prompt = """
Please enter the 3-digits password for opening the Pandora's box.\n 
                                          """)
                # Print a dynamic string
                print(f"\n password = {password}.")
                
                # Control users' input
                try:
                    password = int(password) 
                
                except:
                    print("Try again! It's integer number, like '217', '506'.\n")
                    continue
                
                if password == 123:
                    print("""
The Pandora's Box being open. Instantly, dark clouds and the human world was 
destroyed by the mysterious power...\n
                          """)
                    fail()
                    break # Break the loop
                    
                elif password != 123 and chances_1 > 0:
                    chances_1 -= 1
                    
                elif chances_1 == 0:
                    pandora() # This moves us back to pandora
                    break
                    
                else:
                    pandora() # This moves us back to pandora
                # End of while loops

        # Control users' input and reduce the bug
        elif 'b' in choice_8 or 'put' in choice_8 or 'throw'in choice_8:
            
            # Print the winning message
            print("""
Dear warrior, congratulations! 
In your wisdom and courage, the human world has finally been saved. The sun 
rose as usual and sparkled the earth. The secret of Pandora's Box remained 
forever in the legend...\n
                  """)
    
    # Control users' input and reduce the bug
    elif 'c' in choice_7 or 'can not make choice' in choice_7:
        
        # Print the winning message
        print("""
Dear warrior, congratulations! 
In your wisdom and courage, the human world has finally been saved. The sun 
rose as usual and sparkled the earth. The secret of Pandora's Box remained 
forever in the legend...\n
              """)   
        
    else:
        # Ask users to try to make a new input
        ("Try again!(A or B or C?) You can do it!\n")
        
        # Prompt users to input enter to continue the game
        input(prompt = "<Press enter to continue>\n") 
        
        pandora() # This moves us back to pandora
    # End of this nested conditional statement
        

# Define user function
def fail():
    
    # Print the failure message
    print("""
Game Over!
Thank you for your participation, see you next time!
          """)

start() #EVERYTHING goes before this clause
# Out:
# Dear explorer, you are on a journey to pursue "Pandora's Box." It is the
# mysterious treasure of the ancient world, supposedly containing an enormous
# power that is enough to destroy the entire human race. However, such a treasure
# full of mighty power naturally attracted the evil forces prying eyes. Your
# mission is to find out this box before others to save the world ...
